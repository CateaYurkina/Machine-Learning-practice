# %% [markdown]
# <a href="https://colab.research.google.com/github/CateaYurkina/Machine-Learning-practice/blob/main/ml_trainings.alien_translation/alien_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('Machine-Learning-practice/ml_trainings.alien_translation')  # название папки с клонированным репозиторием

# %%
with open('val', 'r', encoding='utf-8') as file:
    val = file.read()

print(val)
# Out:
# {"dst":"The hosts regrouped, and Bouchard evened the score again, scoring a goal with a 27-37 man advantage.","src":"◘◚ ◞◠▷◫◀◗ ▫◠▨◬◎ ▨◪▦◈◫▦◫ ▫◧▻▱◠◈▪ ◚◪ ◝◂▾▼▷◠◓◈'◬▦ 27:37'◈▴▨◗ ◕◂▱◭ ◀◗◓ ▨▴▢ ◈◠▷◠ ◞▨◂◓◨ ▴◒◗▫▱◪◈◗▵"}
# {"dst":"A new cancer vaccine may teach the immune system to \"see\" abnormal cells","src":"◤◪▦◫ ▨◠▦◞▴◓ ◠◒▪◞▪■ ◀◠◐▪◒◬▨▱▪▨ ◞◫◞▫◪◎◫▦▴ ▨◣▫◭ ▦◫◳◪▫▱◗ ▷▩▼◓◪▱▴◓◫ \"◕◣◓◎▴▽◫\" ◇◐◓◪▫▴◀◫▱◗◓"}
# {"dst":"Currently, language subjects are as popular as science, technology, engineering, and mathematics in the curricula of independent schools and other educational institutions.","src":"▮◪◉◎▴▱◫ ◈◪◓◞▱◪◓ ◧▱◠▦ ◈◗▱ ◈◪◓◞▱◪◓◗■ ◠◓▫▪▨ ◀◠◐◬◎◞▪▢ ◂▨▾▱▱◠◓▪▦ ◚◪ ◈◫◐▴◓ ◂▨◨▱▱◠◓▪▦ ◎▩◍◓◪◈◠▫▱◠◓▪▦◈◠ ◌◪▶◪◄◄ (◌▴▦ ◝◗▱◫◎▱◪◓◫■ ▶▴▨▦◂▱◧▸◫■ ◄◭▷◪▦◈◗◞▱◫▨■ ◄◠▫◪◎◠▫◫▨) ◈▴◓◞▱◪◓◫ ◫▱◪ ▴◒ ◈◪◐▴◓ ▫▾▫◨▱◎◠▨▫◠◈▪◓▵"}
# ...

# %%
with open('test_no_reference', 'r', encoding='utf-8') as file:
    test_no_reference = file.read()

print(test_no_reference)
# Out:
# {"src":"◲▦◠▦◬▦■ ◉◗▢◕◗ ◍◗▱◎ ▽◠▽▪▦◠ ◕▴◉◗▦▼▴ ◀◗◓◉◧▨ ◎▴◞◠▸ ◠▱◈▪▨ ◚◪ ◀◨ ◎◪◞◠▸▱◠◓◬▦ ◀◠▢▪▱◠◓▪ ▻◪▨ ◈◂◞▫◉◠ ◈▴◐◫▱◈◗▵"}
# {"src":"▯▴▥ ◟◧◓▨▱◨ ◀◫◓ ◈◠◈◬■ ◉◂▼◨◐◨▦ ◠▦▦◪◞◗▦◗▦ ▽◠▢◈◬◐▪ ◚◪ ◳◠▦▱▪◒▱▪▨▱◠ ▨▴▦◈◗◞◗▦▴ ◕◣▦◈▴◓◈◗◐◫■ \"◀◫◓ ◞◫◳◠▷◗ ◈◠▷◠\" ◳◠▢◠▦ ◀◗◓ ◎▴◞◠▸◈◠▦ ◞◧▦◓◠ ▨◪▦◈◫◞◗▦◪ ◠◳◓▪◎▼◬▱◬▨ ◳◠▻▪▱◈▪◐▪ ◚◪ ◗◒◫▦◈◪▦ ▨◂◚◨▱◈▾◐▾ ◫◉◫▦ ◉◗◍▫▴ ◈◠◚◠ ◠◉◬▽◂◓▵"}
# {"src":"◡◠▻◧▦ ◂▫◧◎◂◀◗▱ ◍◗◓◎◠◞◬ ◠▦▱◠◒◎◠◞▪▢ ◝◓▴▹◗▫ ◈◨◓▾◎▾▦◈◠ ◞▪▦◬◓◈◠ ◀◪▨▱▴◎◪ ◞◭◓◪◞◫▦◫▦ ◨▢◠◎◠◞▪▦▪▦ ◫▦◞◠▦▱◠◓▪▦ ◗◒◗▦◫ ▨◠▽◀◪▫◎◪◞◫▦◪ ▦▴◈◪▦ ◂▱◠◀◫▱▴▼▴◐◫▦◫ ◞◇◳▱◪◈◗▵"}
# {"src":"◝▾◀◀◠ ▰◠▫◞◂▦ ◚▴ ▰▴◀◀ ▮◫◎▻◞◂▦■ ◞◠◀◠▷ ◂◳▦◠▦◠▦ ◍◂◨◓◀◠▱▱ ◎◠◉▱◠◓▪▦▪▦ ▨◠▷◓◠◎◠▦▪ ▮▴◓◕◫◧ ◆◠◓▼◗◠'▽◬ ◚◪ ○▱▴▹ ▯◂◓▴▦ ◫▱▴ ▴◒▱▴◒▫◗◐◫ ◎◠◉▫◠ ▨◬◞◠ ◞▩◓◪◈◪ ◎◠◐▱▾▻ ▴▫▫◗▵"}
# {"src":"\"○◐▱◠◈◬◐▪▦▪ ◕◣◓◎◪▱◪◓◗▦◪ ◠◞▱◠ ◗▢◫▦ ◚▴◓◎▴■\" ◈◪◈◫ ◀◠▦◠▵"}
# {"src":"▭◠◀▴◓▴ ◕◇◓▴ ▫◠▦▪▨▱◠◓ ◧▱◠▽ ▽◪◓◫▦◈▴▦ ▨◠◉◠▦ ◀◗◓◈▴▦ ◍◠▢▱◠ ◒◭▻▷◪▱◫ ◧▱◈▾◐▾▦◨ ◞◇▽▱◪◈◗■ ◠▦▼◠▨ ▻◂▱◗◞ ◂▱◠◳◠ ▨◠◓◬◒◠▦ ▨◗◒◫ ◞◠▽◬◞▪▦▪ ◀▴▱◗◓▫◎▴◈◗▵"}
# ...

# %%
# !ls -l Machine-Learning-practice
# Out:
# total 300
# -rw-r--r-- 1 root root  40508 Aug  2 12:15  assignment_bagging_and_oob.ipynb
# -rw-r--r-- 1 root root  29104 Aug  2 12:15  assignment_mnist.ipynb
# drwxr-xr-x 3 root root   4096 Aug  2 12:15  ml_trainings.alien_translation
# -rw-r--r-- 1 root root    198 Aug  2 12:15  README.md
# -rw-r--r-- 1 root root 222347 Aug  2 12:15 'Simple samples for practice.ipynb'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# Cloning into 'ваш_репозиторий'...
# fatal: unable to access 'https://github.com/ваш_аккаунт/ваш_репозиторий.git/': The requested URL returned error: 400
#      <input type="file" id="files-c192b00b-2f64-4000-886e-87ed11bb19c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c192b00b-2f64-4000-886e-87ed11bb19c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.git', 'train', 'ml_trainings.alien_translation', 'Simple samples for practice.ipynb', 'Machine-Learning-practice', 'assignment_mnist.ipynb', 'assignment_bagging_and_oob.ipynb', 'README.md', '.gitignore']

# %%
# Настройка git (если еще не настроены)
# !git config --global user.name "CateaYurkina"
# !git config --global user.email "cateayurkinal@gmail.com"

# %%
# Клонируйте репозиторий
# !git clone https://github.com/CateaYurkina/Machine-Learning-practice.git
# Out:
# fatal: destination path 'Machine-Learning-practice' already exists and is not an empty directory.

# %%
# После загрузки файла добавьте его и запушьте
# !git add train
# !git commit -m "Добавил большой файл"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Machine-Learning-practice/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push https://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Z@github.com/CateaYurkina/Machine-Learning-practice.git
# Out:
# fatal: could not read Password for 'https://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Z@github.com': No such device or address

# %%
# !git remote set-url origin git@github.com:CateaYurkina/Machine-Learning-practice.git

# %%
# !git push origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
import subprocess

# Команда для пуша (замените на вашу)
cmd = ["git", "push", "origin", "main"]

# Выполнение команды
result = subprocess.run(cmd, capture_output=True, text=True)

print(result.stdout)
print(result.stderr)
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !ssh-keygen -t ed25519 -C "cateayurkina@gmail.com" -f ~/.ssh/id_ed25519 -N ""
# Out:
# Generating public/private ed25519 key pair.
# /root/.ssh/id_ed25519 already exists.
# Overwrite (y/n)? n

# %%
# !cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAILUGvxSg+jvszUrX9haqEACDDu5d75x0/8fOeipzT7II cateayurkina@gmail.com

# %%
import os

os.makedirs(os.path.expanduser("~/.ssh"), exist_ok=True)

# Запишите конфигурацию
with open(os.path.expanduser("~/.ssh/config"), "w") as f:
    f.write("Host github.com\n\tStrictHostKeyChecking no\n")

# %%
# !chmod 600 ~/.ssh/id_ed25519
# !chmod 600 ~/.ssh/config
# Out:
# chmod: cannot access '/root/.ssh/id_ed25519': No such file or directory
# chmod: cannot access '/root/.ssh/config': No such file or directory

# %%
# !ssh -T git@github.com
# Out:
# Hi CateaYurkina! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 12.96 MiB | 2.75 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:CateaYurkina/Machine-Learning-practice.git
#    d4ec87a..5ee97dd  main -> main

# %%
# !git clone https://github.com/CateaYurkina/Machine-Learning-practice.git
# Out:
# Cloning into 'Machine-Learning-practice'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 50 (delta 18), reused 3 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 13.30 MiB | 11.41 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
with open('train', 'r', encoding='utf-8') as file:
    train = file.read()

# %%
print(train)
# Out:
# Buffered data was truncated after reaching the output size limit.
